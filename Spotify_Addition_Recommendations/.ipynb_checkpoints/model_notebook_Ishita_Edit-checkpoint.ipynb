# %% [markdown]
# ## 3 May 2023 Model Notebook
#
# Development Logic:
# 1. After today's discussion, we may decide to put energy and loudness as our y value for this KNN model, becuase loudness is one of the most important aspect for a song to be in a certain playlist.

# %%
import pandas as pd  # dataset
import seaborn as sns  #visualization (plottings)
import matplotlib.pyplot as plt  #visualization
import numpy as np  # arrays, algebra, dealing with numbers
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_squared_error, accuracy_score, precision_score, recall_score

# %%
# music= pd.read_csv('./scaled_music.csv')
# music= pd.read_csv('./songs.csv')
# display(music.head())

music_dataset = pd.read_csv('songs.csv', encoding='ISO-8859-1')

# this will be the scraped datase. We need to rename it appropriately later
music_dataset
# Out:
#                                              Name  Danceability  Energy  Key  \
# 0               Everybody Wants To Rule The World         0.645   0.795    7
# 1                                      Take on Me         0.573   0.902    6
# 2                             Sweet Child O' Mine         0.446   0.952    6
# 3                              Livin' On A Prayer         0.532   0.887    0
# 4          Running Up That Hill (A Deal With God)         0.629   0.545   10
# ..                                            ...           ...     ...  ...
# 95              You Spin Me Round (Like a Record)         0.554   0.963    6
# 96  Hungry Eyes - From "Dirty Dancing" Soundtrack         0.712   0.549    5
# 97                                          Gypsy         0.622   0.540    5
# 98                                   Red Red Wine         0.857   0.468    1
# 99   Another One Bites The Dust - Remastered 2011         0.933   0.528    5
#
#     Loudness  Mode  Speechiness  Acousticness  Instrumentalness  Liveness  \
# 0    -12.095     1       0.0527      0.347000          0.003890    0.1040
# 1     -7.638     0       0.0540      0.018000          0.001250    0.0928
# 2     -5.321     1       0.0523      0.090100          0.085700    0.1120
# 3     -3.757     1       0.0335      0.077800          0.000214    0.2940
# 4    -13.123     0       0.0546      0.719000          0.003080    0.0604
# ..       ...   ...          ...           ...               ...       ...
# 95    -3.762     0       0.0350      0.000244          0.070200    0.4310
# 96    -9.484     1       0.0254      0.011000          0.000000    0.1180
# 97   -13.990     1       0.0261      0.017000          0.007710    0.2650
# 98    -8.530     1       0.0476      0.004140          0.000013    0.2690
# 99    -6.472     0       0.1620      0.112000          0.329000    0.1630
#
#     Valence    Tempo  Duration (ms)
# 0     0.535  112.067         251489
# 1     0.876   84.412         225280
# 2     0.624  125.303         356067
# 3     0.795  122.511         249293
# 4     0.194  108.376         298933
# ..      ...      ...            ...
# 95    0.918  128.175         195147
# 96    0.552  109.882         251067
# 97    0.847  130.879         264907
# 98    0.843   89.119         183733
# 99    0.756  109.975         214653
#
# [100 rows x 13 columns]

# %%
# for feature in music_dataset.columns:
#     sns.FacetGrid(music_dataset, height=5) \
#         .map(sns.histplot, feature, kde=True, stat="density", kde_kws=dict(cut=3)) \
#         .add_legend();

# %%
plt.figure(figsize = (12,8))
mask = np.tril(music_dataset.corr())
sns.heatmap(music_dataset.corr(), annot=True, cmap='PRGn', mask=mask, square=False)
# Out:
# C:\Users\26366\AppData\Local\Temp\ipykernel_31648\1742031916.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mask = np.tril(music_dataset.corr())
# C:\Users\26366\AppData\Local\Temp\ipykernel_31648\1742031916.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(music_dataset.corr(), annot=True, cmap='PRGn', mask=mask, square=False)
# <Axes: >

# %%
# Adding one dummy column to the dataframe which categorize all those energy values into six different categories.
# Now the dataframe has been properly updated
music_dataset['energy_category'] = music_dataset['Energy'] // 0.002
print(music_dataset['energy_category'].head())
sns.FacetGrid(music_dataset, height=5) \
    .map(sns.histplot, 'energy_category', kde=True, stat="density", kde_kws=dict(cut=1)) \
    .add_legend();
# Out:
# 0    397.0
# 1    451.0
# 2    475.0
# 3    443.0
# 4    272.0
# Name: energy_category, dtype: float64

# %%
# Spliting the data into train and test. We will do a 80:20 split.
music_dataset_used = music_dataset.drop(columns = ['Energy', 'Duration (ms)', 'Key', 'Speechiness', 'Mode', 'Name'], axis = 1)
train, test = train_test_split(music_dataset_used, test_size=0.01, random_state=1)
X_train = train.drop('energy_category', axis = 1)
y_train = train['energy_category']
X_test = test.drop('energy_category', axis = 1)
y_test = test['energy_category']

print(X_train.head())
print(X_test.head())
# Out:
#     Danceability  Loudness  Acousticness  Instrumentalness  Liveness  Valence  \
# 2          0.446    -5.321        0.0901          0.085700    0.1120    0.624
# 73         0.768    -5.109        0.0964          0.000029    0.0970    0.962
# 97         0.622   -13.990        0.0170          0.007710    0.2650    0.847
# 62         0.653   -10.613        0.0115          0.000010    0.0776    0.894
# 19         0.477   -10.036        0.1930          0.000002    0.1310    0.423
#
#       Tempo
# 2   125.303
# 73  118.773
# 97  130.879
# 62  108.709
# 19   81.204
#     Danceability  Loudness  Acousticness  Instrumentalness  Liveness  Valence  \
# 80         0.692   -10.533        0.0811          0.000000    0.0848    0.468
# 84         0.780    -7.320        0.7360          0.002690    0.0630    0.365
# 33         0.776    -3.704        0.0495          0.000008    0.1970    0.918
# 81         0.878    -9.875        0.1260          0.046100    0.1830    0.947
# 93         0.685   -10.616        0.2880          0.009180    0.1240    0.939
#
#       Tempo
# 80   74.375
# 84  101.967
# 33  138.827
# 81  118.881
# 93  134.546

# %%
# Construct the KNN models with the data already in hand
neigh = KNeighborsClassifier(n_neighbors=24)
# The model is properly trained here
neigh_fit = neigh.fit(X_train, y_train)

# %%
# This cell predicts the Energy level in order to check the model
pred = neigh.predict(X_test)
print("Accuracy : ", accuracy_score(y_test, pred))
print("Mean Square Error : ", mean_squared_error(y_test, pred))
# Out:
# Accuracy :  0.0
# Mean Square Error :  15360.5

# %%
# Combine the two cells above. Find the best number for k
best_iteration = 0
current_highest_accuracy = 0
results = {}
for i in range(1, 80):
    neigh = KNeighborsClassifier(n_neighbors=i)
    # The model is properly trained here
    neigh_fit = neigh.fit(X_train, y_train)
    pred = neigh.predict(X_test)
    accuracy_val = accuracy_score(y_test, pred)
    results[i] = accuracy_val
    if (accuracy_val > current_highest_accuracy):
        current_highest_accuracy = accuracy_val
        best_iteration = i
print("{} as K gives the best accuracy for {}".format(best_iteration, current_highest_accuracy))
# Out:
# 0 as K gives the best accuracy for 0

# %%
plt.plot(results.keys(), results.values())

# %%
# Construct the KNN models with the data already in hand
neigh = KNeighborsClassifier(n_neighbors=35)
# The model is properly trained here
neigh_fit = neigh.fit(X_train, y_train)
