# %% [markdown]
# ## Boquan's Data Explore

# %% [markdown]
# ## Inporting Libraries

# %%
import seaborn as sns
import numpy as np
from numpy import where
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Plot the First Three Columes

# %%
sns.set_style("whitegrid")
spotify = pd.read_csv("Spotify_Youtube.csv", usecols=[3, 4, 5])
# spotify.drop('Artist', axis = 1)

sns.pairplot(spotify)

# %% [markdown]
# ## Analysis About the Data

# %% [markdown]
# We should observe the diagnose of the pairplot to see the data distribution. For the attribute key, it is fluctuating and we need to figure out what exactly the name key is refering to. For the lest, they are all right screwed. Maybe further tranformation is needed.
