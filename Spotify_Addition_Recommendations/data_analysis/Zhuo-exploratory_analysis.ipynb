# %% [markdown]
# ## Zhuo's Data Explore

# %% [markdown]
# ## Inporting Libraries

# %%
import seaborn as sns
import numpy as np
from numpy import where
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Plot the First Three Columes

# %%
sns.set_style("whitegrid")
spotify = pd.read_csv("Spotify_Youtube.csv", usecols=[9, 10, 11])
# spotify.drop('Artist', axis = 1)

sns.pairplot(spotify)

# %% [markdown]
# ## Analysis About the Data

# %% [markdown]
# From the data distribution, all the three attributes clearly show their trend and relationship with each other. We wouldn't need tranformation for this one.
